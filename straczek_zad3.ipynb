# %% [markdown]
# Jakub Strączek, Zadanie 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Rysowanie wykresow

# %%
def plot(start, stop, amt, title):
    f = lambda x : x**2 + 5
    x = np.linspace(start, stop, amt)
    y = [f(i) for i in x]

    plt.figure()
    plt.plot(x, y)
    plt.title(title)
    plt.xlabel('X')
    plt.ylabel('Y')
    
plot(-1, 1, 30, 'Wykres 1')
plot(-6, 6, 30, 'Wykres 2')
plot(0, 5, 30, 'Wykres 3')

# %% [markdown]
# Inicjalizacja ramki + info

# %%
d = {'name' : ['Marek', 'Jadzia', 'Jan', 'Jakub', 'Aleksander'],
     'surname' : ['Nowak', 'Kulikowski', 'Cztery', 'Maslo', 'Brokul'],
     'sex': ['male', 'female', 'notspecified', 'none', 'null']}
frame = pd.DataFrame(d)

frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   sex      5 non-null      object
# dtypes: object(3)
# memory usage: 248.0+ bytes

# %% [markdown]
# Wyswietlenie opisu ramki

# %%
frame.describe()
# Out:
#          name surname   sex
# count       5       5     5
# unique      5       5     5
# top     Marek   Maslo  male
# freq        1       1     1

# %% [markdown]
# Wyswietlenie headu

# %%
frame.head(3)
# Out:
#      name     surname           sex
# 0   Marek       Nowak          male
# 1  Jadzia  Kulikowski        female
# 2     Jan      Cztery  notspecified
